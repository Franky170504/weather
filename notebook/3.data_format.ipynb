# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mlt
import os 
import sys

# %%
file_paths = {
    "max_temperature": "data/_2019/_attributes/max_temperature.csv",
    "mean_temperature": "data/_2019/_attributes/mean_temperature.csv",
    "max_precipitation": "data/_2019/_attributes/max_precipitation.csv",
    "mean_precipitation": "data/_2019/_attributes/mean_precipitation.csv",
    "mslp": "data/_2019/_attributes/mslp.csv",
}

# Initialize an empty list to store DataFrames
dfs = []

# Read each CSV and extract relevant columns
for name, path in file_paths.items():
    df = pd.read_csv(path)
    # Identify unique columns (excluding common ones)
    unique_cols = [col for col in df.columns if col not in ['valid_time', 'latitude', 'longitude']]
    if unique_cols:
        unique_col = unique_cols[0]  # Assuming one unique column per file
        df = df[['valid_time', 'latitude', 'longitude', unique_col]]
        df.rename(columns={unique_col: name}, inplace=True)  # Rename to file-specific name
        dfs.append(df)

# Merge all DataFrames on common columns
merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df, on=['valid_time', 'latitude', 'longitude'], how='outer')

# Save to a new CSV file
if os.path.exists("data/_2019/_merged/merged_data.csv"):
    print("File alreay exists")
else:
    merged_df.to_csv("data/_2019/_merged/merged_data.csv", index=False)
    print("File created")

# Display the merged DataFrame head
# Out:
# File alreay exists

# %%
df = pd.read_csv("data\_2019\_merged\merged_data.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# C:\Users\david\AppData\Local\Temp\ipykernel_24504\1042311228.py:1: SyntaxWarning: invalid escape sequence '\_'
#   df = pd.read_csv("data\_2019\_merged\merged_data.csv")
#     valid_time  latitude  longitude  max_temperature  mean_temperature  \
# 0     01-01-19     18.80       72.8        299.21042         296.81256
# 1     01-01-19     19.05       72.8        299.89655         296.60733
# 2     02-01-19     18.80       72.8        297.98640         296.14690
# 3     02-01-19     19.05       72.8        298.66342         296.00150
# 4     03-01-19     18.80       72.8        298.41232         297.29196
# ..         ...       ...        ...              ...               ...
# 725   31/08/19     19.05       72.8        301.20790         300.36288
# 726   31/10/19     18.80       72.8        303.76712         302.06754
# 727   31/10/19     19.05       72.8        304.31934         302.15308
# 728   31/12/19     18.80       72.8        298.12000         296.77167
# 729   31/12/19     19.05       72.8        298.48940         296.60070
#
#      max_precipitation  mean_precipitation        mslp
# 0         0.000000e+00        0.000000e+00  101726.086
# 1         0.000000e+00        0.000000e+00  101731.230
# 2         0.000000e+00        0.000000e+00  101423.414
# 3         0.000000e+00        0.000000e+00  101425.870
# 4         0.000000e+00        0.000000e+00  101055.555
# ..                 ...                 ...         ...
# 725       2.181087e-03        1.150392e-03  100295.530
# 726       5.240000e-05        2.280000e-06  100909.555
# 727       3.180000e-05        1.400000e-06  100918.510
# 728       9.530000e-08        3.970000e-09  101329.120
# 729       0.000000e+00        0.000000e+00  101330.305
#
# [730 rows x 8 columns]
