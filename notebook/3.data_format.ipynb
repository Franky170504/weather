# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mlt
import os 
import sys

# %%
file_paths = {
    "max_temperature": "data/_2020/_attributes/max_temperature.csv",
    "mean_temperature": "data/_2020/_attributes/mean_temperature.csv",
    "max_precipitation": "data/_2020/_attributes/max_precipitation.csv",
    "mean_precipitation": "data/_2020/_attributes/mean_precipitation.csv",
    "mslp": "data/_2020/_attributes/mslp.csv",
}

# Initialize an empty list to store DataFrames
dfs = []

# Read each CSV and extract relevant columns
for name, path in file_paths.items():
    df = pd.read_csv(path)
    # Identify unique columns (excluding common ones)
    unique_cols = [col for col in df.columns if col not in ['valid_time', 'latitude', 'longitude']]
    if unique_cols:
        unique_col = unique_cols[0]  # Assuming one unique column per file
        df = df[['valid_time', 'latitude', 'longitude', unique_col]]
        df.rename(columns={unique_col: name}, inplace=True)  # Rename to file-specific name
        dfs.append(df)

# Merge all DataFrames on common columns
merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df, on=['valid_time', 'latitude', 'longitude'], how='outer')

# Save to a new CSV file
if os.path.exists("data/_2020/_merged/merged_data.csv"):
    print("File alreay exists")
else:
    merged_df.to_csv("data/_2020/_merged/merged_data.csv", index=False)
    print("File created")

# Display the merged DataFrame head
# Out:
# File created

# %%
df = pd.read_csv("data\_2020\_merged\merged_data.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# C:\Users\david\AppData\Local\Temp\ipykernel_22008\3659541908.py:1: SyntaxWarning: invalid escape sequence '\_'
#   df = pd.read_csv("data\_2020\_merged\merged_data.csv")
#      valid_time  latitude  longitude  max_temperature  mean_temperature  \
# 0    2020-01-01     18.80       72.8        297.62848         296.29350
# 1    2020-01-01     19.05       72.8        297.88880         295.97708
# 2    2020-01-02     18.80       72.8        298.00750         296.72770
# 3    2020-01-02     19.05       72.8        298.30860         296.46840
# 4    2020-01-03     18.80       72.8        297.79413         296.30576
# ..          ...       ...        ...              ...               ...
# 727  2020-12-29     19.05       72.8        299.18690         296.44910
# 728  2020-12-30     18.80       72.8        299.17847         297.07205
# 729  2020-12-30     19.05       72.8        299.79175         296.84286
# 730  2020-12-31     18.80       72.8        301.40393         298.39780
# 731  2020-12-31     19.05       72.8        301.74673         298.11102
#
#      max_precipitation  mean_precipitation        mslp
# 0         0.000000e+00        0.000000e+00  101397.630
# 1         3.814348e-07        1.589312e-08  101398.530
# 2         0.000000e+00        0.000000e+00  101585.710
# 3         0.000000e+00        0.000000e+00  101587.625
# 4         7.630219e-07        5.166165e-08  101547.220
# ..                 ...                 ...         ...
# 727       0.000000e+00        0.000000e+00  101163.555
# 728       0.000000e+00        0.000000e+00  101152.980
# 729       0.000000e+00        0.000000e+00  101159.350
# 730       0.000000e+00        0.000000e+00  101114.270
# 731       0.000000e+00        0.000000e+00  101122.910
#
# [732 rows x 8 columns]
